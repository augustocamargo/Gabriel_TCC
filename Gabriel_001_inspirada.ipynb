# %%
# Install virtual environment package
# !pip install --upgrade virtualenv

# Create a virtual environment
# !virtualenv myenv

# Activate the virtual environment
exec(open('myenv/bin/activate_this.py').read(), {'__file__': 'myenv/bin/activate_this.py'})

# Check installed packages
# !pip freeze

# !source myenv/bin/activate

# !pip3 freeze
# !mkdir content
# Out:
# WARNING: Keyring is skipped due to an exception: Failed to unlock the collection!
# ...
#      |████████████████████████████████| 3.7 MB 17.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 468 kB 83.6 MB/s eta 0:00:01
# ...
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.0.12
#     Uninstalling filelock-3.0.12:
#       Successfully uninstalled filelock-3.0.12
# ...
# created virtual environment CPython3.8.5.final.0-64 in 377ms
#   creator CPython3Posix(dest=/home/augustoc/projects/gabriel/myenv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/home/augustoc/.local/share/virtualenv)
#     added seed packages: pip==23.2.1, setuptools==68.2.0, wheel==0.41.2
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# Dados vindos do TCC do Gabriel
# https://figshare.com/s/87d7b94c9f3f85c8410f
# !rm -rf content/data ; mkdir content/data
# !wget --no-check-certificate 'https://figshare.com/ndownloader/files/42522937?private_link=87d7b94c9f3f85c8410f' -O 'paciente.zip'
# !mv paciente.zip content/data ; cd content/data ; unzip paciente.zip ; rm paciente.zip
# Out:
# --2023-10-01 20:49:19--  https://figshare.com/ndownloader/files/42522937?private_link=87d7b94c9f3f85c8410f
# Resolving figshare.com (figshare.com)... 52.31.154.4, 34.248.41.179
# Connecting to figshare.com (figshare.com)|52.31.154.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/42522937/pacientes001.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20231001/eu-west-1/s3/aws4_request&X-Amz-Date=20231001T234919Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=035f7e0a00143c88ca55550999bc3ac9dcb1f85ed0b3238b71b48bf28ee13498 [following]
# ...

# %%
# Codigo do "Primeiro Commit" do TCC
# https://github.com/gabrielrstan/TCC/archive/2c3e4e2a04216880b86356f2cda89b1436f44b3b.zip
# https://github.com/augustocamargo/Gabriel_TCC/archive/refs/heads/main.zip
# !rm -rf content/code ; mkdir content/code
# !wget https://github.com/augustocamargo/Gabriel_TCC/archive/refs/heads/main.zip
# !mv main.zip content/code ; cd content/code ; unzip main.zip ; mv Gabriel_TCC-main/* . ; rm main.zip ; rm -rf Gabriel_TCC-main/
import sys
sys.path.insert(0,'content/code/')
# Out:
# --2023-10-01 21:35:58--  https://github.com/augustocamargo/Gabriel_TCC/archive/refs/heads/main.zip
# Resolving github.com (github.com)... 20.201.28.151
# Connecting to github.com (github.com)|20.201.28.151|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/augustocamargo/Gabriel_TCC/zip/refs/heads/main [following]
# --2023-10-01 21:35:59--  https://codeload.github.com/augustocamargo/Gabriel_TCC/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 20.201.28.149
# Connecting to codeload.github.com (codeload.github.com)|20.201.28.149|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘main.zip’
#
# main.zip                [ <=>                ]  12,36K  --.-KB/s    in 0,002s
#
# 2023-10-01 21:35:59 (6,81 MB/s) - ‘main.zip’ saved [12655]
#
# Archive:  main.zip
# 64c3e2ef9fea56888d84caae77775c48ce97c2d1
#    creating: Gabriel_TCC-main/
# ...

# %%
# Requirements
# !pip install -r 'content/code/requirements.txt'
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 3.8 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 1.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 11.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 8.1 MB/s eta 0:00:00:00:010:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 2.3 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 14.0 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 35.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 30.5 MB/s eta 0:00:0000:0100:01
# ...
#   Obtaining dependency information for audioread>=2.1.9 from https://files.pythonhosted.org/packages/57/8d/30aa32745af16af0a9a650115fbe81bde7c610ed5c21b381fca0196f3a7f/audioread-3.0.1-py3-none-any.whl.metadata
# ...

# %%
# Time to run
import time
inicio = time.time()
# !python content/code/main.py
fim = time.time()
print("exec time:",fim-inicio)
# Out:
# /home/augustoc/projects/gabriel/myenv/lib/python3.8/site-packages/lazy_loader/__init__.py:185: RuntimeWarning: subpackages can technically be lazily loaded, but it causes the package to be eagerly loaded even if it is already lazily loaded.So, you probably shouldn't use subpackages with this lazy feature.
#   warnings.warn(msg, RuntimeWarning)
# /home/augustoc/projects/gabriel/myenv/lib/python3.8/site-packages/lazy_loader/__init__.py:185: RuntimeWarning: subpackages can technically be lazily loaded, but it causes the package to be eagerly loaded even if it is already lazily loaded.So, you probably shouldn't use subpackages with this lazy feature.
#   warnings.warn(msg, RuntimeWarning)
#
# ### Época ### 0
#
# ~~~ TREINO ~~~
# custo 0.11479922873113235
#
# ~~~ FIM TREINO ~~~
#
#
# ~~~ VALIDAÇÂO ~~~
# custo 0.15923865468289372
#
# BEST MODEL:
#  Loss:0.15923865468289372
#  Epoca:0
# ~~~ FIM VALIDAÇÂO ~~~
#
#
# ### Exec Time:  54.68359565734863 ###
#
# ### Época ### 1
#
# ~~~ TREINO ~~~
# ...
